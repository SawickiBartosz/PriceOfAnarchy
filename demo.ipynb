# %%
from dtos import q, Graph

G = Graph('A', 'D', [
    ('A', 'B', q(0,1,0)),
    ('A', 'C', q(0,0,10)),
    ('C', 'B', q(0,1,0)),
    ('B', 'D', q(0,0,10)),
    ('C', 'D', q(0,1,0))
])
G.draw()
print(G.possible_paths())
# Out:
# [['A', 'B', 'C', 'D'], ['A', 'B', 'D'], ['A', 'C', 'B', 'D'], ['A', 'C', 'D']]
