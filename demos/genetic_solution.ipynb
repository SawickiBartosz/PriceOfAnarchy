# %%
import demo_fix
from dtos import q, Graph, Flow
from solutions import GeneticSolution, TargetOptimal
from common import DiscreteCore, ContinuousCore

G = Graph('A', 'D', [
    ('A', 'B', q(0,1,0)),
    ('A', 'C', q(0,0,10)),
    ('C', 'B', q(0,1,0)),
    ('B', 'D', q(0,0,10)),
    ('C', 'D', q(0,1,0))
])
solution = GeneticSolution(G, num_generations=100, sol_per_pop=100).solve(DiscreteCore(10), TargetOptimal())
solution.draw()
# Out:
# TargetNE cannot be used in solutions that don't provide a path
# Traceback (most recent call last):
#   File "C:\Users\Aurif\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pygad\pygad.py", line 1688, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "d:\PW\GameTheory\PriceOfAnarchy\solutions\genetic.py", line 26, in fitness_func
#     return -target.calc(Flow(self.graph, {path: solution[idx] for idx, path in enumerate(paths)}), path=None)
#   File "d:\PW\GameTheory\PriceOfAnarchy\solutions\targets\ne.py", line 8, in calc
#     raise ValueError("TargetNE cannot be used in solutions that don't provide a path")
# ValueError: TargetNE cannot be used in solutions that don't provide a path
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %%
solution = GeneticSolution(G).solve(ContinuousCore(10), TargetOptimal())
solution.draw()
# Out:
# Flow(cost: 150.00000002038743, {('A', 'B', 'C', 'D'): 2.1101844601299225e-15, ('A', 'B', 'D'): 5.0001009665777705, ('A', 'C', 'B', 'D'): 2.99198241429303e-16, ('A', 'C', 'D'): 4.9998990334221745})
