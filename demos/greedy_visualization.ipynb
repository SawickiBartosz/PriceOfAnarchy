# %%
import demo_fix
from dtos import q, Graph, Flow
from solutions import GreedySolution, TargetOptimal, TargetNE
from common import DiscreteCore
from visualization import Plotter

G = Graph('A', 'D', [
    ('A', 'B', q(0,1,0)),
    ('A', 'C', q(0,0,10)),
    ('C', 'B', q(0,1,0)),
    ('B', 'D', q(0,0,10)),
    ('C', 'D', q(0,1,0))
])
solution = GreedySolution(G).solve(DiscreteCore(10), TargetOptimal(), attach=Plotter())
solution.draw()
# Out:
# None
# path_increased=('A', 'B', 'C', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'B', 'C', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'B', 'C', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'B', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'C', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'B', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'C', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'B', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'C', 'D') value=1.0 path_decreased=None
# path_increased=('A', 'B', 'D') value=1.0 path_decreased=None
# Flow(cost: 164.0, {('A', 'B', 'C', 'D'): 3.0, ('A', 'B', 'D'): 4.0, ('A', 'C', 'B', 'D'): 0.0, ('A', 'C', 'D'): 3.0})

# %%
solution = Flow(G, {
    ('A', 'B', 'D'): 5, 
    ('A', 'C', 'D'): 5
})
solution.draw();
# Out:
# Warning: unspecified paths [('A', 'B', 'C', 'D'), ('A', 'C', 'B', 'D')], assuming 0.
