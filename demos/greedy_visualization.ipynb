# %%
import demo_fix
from dtos import q, Graph, Flow
from solutions import GreedySolution, RotatingGreedySolution, TargetOptimal
from common import DiscreteCore
from visualization import Plotter

G = Graph('A', 'D', [
    ('A', 'B', q(0,1,0)),
    ('A', 'C', q(0,0,10)),
    ('C', 'B', q(0,1,0)),
    ('B', 'D', q(0,0,10)),
    ('C', 'D', q(0,1,0))
])
solution = GreedySolution(G).solve(DiscreteCore(10), TargetOptimal(), attach=Plotter())

# %%
solution = RotatingGreedySolution(G).solve(DiscreteCore(10), TargetOptimal(), attach=Plotter())

# %%
solution = Flow(G, {
    ('A', 'B', 'D'): 5, 
    ('A', 'C', 'D'): 5
})
solution.draw();
