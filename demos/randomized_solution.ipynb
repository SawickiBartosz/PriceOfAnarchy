# %%
import demo_fix
from dtos import q, Graph
from solutions import RandomizedSolution, ContinuousCore, DiscreteCore

G = Graph('A', 'D', [
    ('A', 'B', q(0,1,0)),
    ('A', 'C', q(0,0,10)),
    ('C', 'B', q(0,1,0)),
    ('B', 'D', q(0,0,10)),
    ('C', 'D', q(0,1,0))
])
solution = RandomizedSolution(G).solve(ContinuousCore())
solution.draw()
# Out:
# Flow(cost: 7.129175406380396, {('A', 'B', 'C', 'D'): 0.4962960476902845, ('A', 'B', 'D'): 0.21194909350832994, ('A', 'C', 'B', 'D'): 0.07558696552704171, ('A', 'C', 'D'): 0.216167893274344})

# %%
solution = RandomizedSolution(G).solve(ContinuousCore(), seed=7)
solution.draw()
# Out:
# Flow(cost: 11.382589470654, {('A', 'B', 'C', 'D'): 0.24773895628901887, ('A', 'B', 'D'): 0.3555853825458644, ('A', 'C', 'B', 'D'): 0.30742114377099644, ('A', 'C', 'D'): 0.08925451739412031})

# %%
solution = RandomizedSolution(G).solve(ContinuousCore(3), seed=7)
solution.draw()
# Out:
# Flow(cost: 38.86237398696735, {('A', 'B', 'C', 'D'): 0.7432168688670566, ('A', 'B', 'D'): 1.0667561476375933, ('A', 'C', 'B', 'D'): 0.9222634313129894, ('A', 'C', 'D'): 0.2677635521823609})

# %%
solution = RandomizedSolution(G).solve(DiscreteCore(10), seed=7)
solution.draw()
# Out:
# Flow(cost: 180.0, {('A', 'B', 'C', 'D'): 2.0, ('A', 'B', 'D'): 4.0, ('A', 'C', 'B', 'D'): 3.0, ('A', 'C', 'D'): 1.0})
