# %%
import demo_fix
from dtos import q, Graph, Flow
from solutions import DynamicSolution, TargetOptimal
from common import DiscreteCore
from visualization import Plotter

G = Graph('A', 'D', [
    ('A', 'B', q(0,1,0)),
    ('A', 'C', q(0,0,10)),
    ('C', 'B', q(0,1,0)),
    ('B', 'D', q(0,0,10)),
    ('C', 'D', q(0,1,0))
])
solution = DynamicSolution(G).solve(DiscreteCore(10), TargetOptimal(), attach=Plotter())
# Out:
# None
# <TemporaryDirectory 'C:\\Users\\stani\\AppData\\Local\\Temp\\tmpstn_qx_c'>
# path_increased=('A', 'B', 'D') value=1.0 path_decreased=None
# <TemporaryDirectory 'C:\\Users\\stani\\AppData\\Local\\Temp\\tmpstn_qx_c'>
# path_increased=('A', 'C', 'D') value=1.0 path_decreased=None
# <TemporaryDirectory 'C:\\Users\\stani\\AppData\\Local\\Temp\\tmpstn_qx_c'>
# path_increased=('A', 'C', 'D') value=1.0 path_decreased=None
# <TemporaryDirectory 'C:\\Users\\stani\\AppData\\Local\\Temp\\tmpstn_qx_c'>
# path_increased=('A', 'B', 'D') value=1.0 path_decreased=None
# <TemporaryDirectory 'C:\\Users\\stani\\AppData\\Local\\Temp\\tmpstn_qx_c'>

# %%
solution = Flow(G, {
    ('A', 'B', 'D'): 5, 
    ('A', 'C', 'D'): 5
})
solution.draw();
